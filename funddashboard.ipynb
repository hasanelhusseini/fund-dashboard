# %%
# ===================================================
# Graduate Programme – Panel Assessment
# Fund Controlling (Complete Python Solution)
# ===================================================

import pandas as pd
import numpy as np
import plotly.express as px
from ipywidgets import interact, FloatSlider
from IPython.display import display

# ---- Load dataset ----
file_path = "/2025 Graduate Programme - Assessment Data Set- Fund Controlling.xlsx"
data = pd.read_excel(file_path, sheet_name=" Dataset")

print("✅ Dataset Loaded Successfully")
print("Columns:", data.columns.tolist())
print(data.head())

# ===================================================
# 1. Dashboard of Fund Performance
# ===================================================
fig = px.line(
    data,
    x="Month", y="Monthly Return",
    color="Fund Name",
    markers=True,
    title="Fund Performance Over Time"
)
fig.update_layout(
    xaxis_title="Month",
    yaxis_title="Monthly Return",
    legend_title="Fund Name"
)
fig.show()

# ===================================================
# 2. Risk vs Return Comparison
# ===================================================
risk_return = data.groupby("Fund Name").agg({
    "Monthly Return": "mean",
    "Volatility": "mean"
}).reset_index()

# Bubble sizes proportional to absolute return
risk_return["Size"] = (risk_return["Monthly Return"].abs() * 100).clip(lower=5)

fig2 = px.scatter(
    risk_return,
    x="Volatility",
    y="Monthly Return",
    color="Fund Name",
    size="Size",
    hover_name="Fund Name",
    text="Fund Name",
    title="Risk vs Return Comparison"
)
fig2.update_traces(textposition="top center")
fig2.show()

# ===================================================
# 3. Average Monthly Returns
# ===================================================
avg_returns = data.groupby("Fund Name")["Monthly Return"].mean().reset_index()
avg_returns.columns = ["Fund Name", "Avg Monthly Return"]

print("\n📊 Average Monthly Returns:")
display(avg_returns)

# ===================================================
# 4. Highest/Lowest Risk Investments
# ===================================================
highest_risk = risk_return.loc[risk_return["Volatility"].idxmax()]
lowest_risk = risk_return.loc[risk_return["Volatility"].idxmin()]

print("\n⚠️ Highest Risk Investment:")
display(highest_risk.to_frame().T)

print("\n✅ Lowest Risk Investment:")
display(lowest_risk.to_frame().T)

# ===================================================
# 5. Monthly Return Ranking (Top 3 / Bottom 3)
# ===================================================
ranking_counts = []
for month, subdf in data.groupby("Month"):
    subdf = subdf.sort_values("Monthly Return", ascending=False)
    subdf["Rank"] = range(1, len(subdf)+1)
    ranking_counts.append(subdf)

ranking_df = pd.concat(ranking_counts)

top3_counts = ranking_df[ranking_df["Rank"] <= 3].groupby("Fund Name").size()
bottom3_counts = ranking_df[ranking_df["Rank"] > (len(risk_return) - 3)].groupby("Fund Name").size()

print("\n🏆 Top 3 appearances:")
display(top3_counts)

print("\n⬇️ Bottom 3 appearances:")
display(bottom3_counts)

# ===================================================
# 6. Asset Allocation Consistency
# ===================================================
alloc_cols = ["Equity Allocation (%)", "Bond Allocation (%)", "Cash Allocation (%)"]
alloc_stability = data.groupby("Fund Name")[alloc_cols].std().mean(axis=1).reset_index()
alloc_stability.columns = ["Fund Name","Avg Allocation Std"]

most_stable = alloc_stability.loc[alloc_stability["Avg Allocation Std"].idxmin()]
least_stable = alloc_stability.loc[alloc_stability["Avg Allocation Std"].idxmax()]

print("\n📉 Most Stable Allocation:")
display(most_stable.to_frame().T)

print("\n📈 Least Stable Allocation:")
display(least_stable.to_frame().T)

# ===================================================
# 7. Cash Allocation Validation
# ===================================================
data["Total Alloc"] = data[alloc_cols].sum(axis=1)
data["Cash Corrected"] = data["Cash Allocation (%)"]

# Fix negatives
data.loc[data["Cash Corrected"] < 0, "Cash Corrected"] = 0
# Adjust so total = 100
data["Cash Corrected"] = data["Cash Corrected"] + (100 - data["Total Alloc"])

print("\n💵 Cash Allocation Validation (sample rows):")
display(data[[
    "Month","Fund Name",
    "Equity Allocation (%)","Bond Allocation (%)",
    "Cash Allocation (%)","Cash Corrected","Total Alloc"
]].head())

# ===================================================
# 8. Fund Summary Report
# ===================================================
summary = data.groupby("Fund Name").agg({
    "Monthly Return": "mean",
    "Volatility": "mean",
    "Equity Allocation (%)": "mean",
    "Bond Allocation (%)": "mean",
    "Cash Corrected": "mean"
}).reset_index()

summary.columns = ["Fund Name","Avg Return","Avg Risk","Avg Equity","Avg Bonds","Avg Cash"]

print("\n📑 Fund Summary Report:")
display(summary)

# ===================================================
# Part 2: Interactive Tool for Investor Selection
# ===================================================
def fund_selector(max_risk, min_return):
    """Filter funds by investor’s risk appetite and return expectation"""
    filtered = summary[(summary["Avg Risk"] <= max_risk) &
                       (summary["Avg Return"] >= min_return)]
    if filtered.empty:
        print("⚠️ No funds match this criteria.")
    else:
        print(f"\n🎯 Funds with Risk ≤ {max_risk:.3f} and Return ≥ {min_return:.3f}:")
        display(filtered)

# Interactive sliders
interact(
    fund_selector,
    max_risk=FloatSlider(value=0.05, min=0, max=0.1, step=0.005, description="Max Risk"),
    min_return=FloatSlider(value=0.0, min=-0.05, max=0.05, step=0.005, description="Min Return")
)
# Out:
# ✅ Dataset Loaded Successfully
# Columns: ['Fund Name', 'Month', 'Monthly Return', 'Volatility', 'Equity Allocation (%)', 'Bond Allocation (%)', 'Cash Allocation (%)']
#   Fund Name     Month  Monthly Return  Volatility  Equity Allocation (%)  \
# 0     Alpha  Jan-2023          0.0199      0.0320                  63.95
# 1      Beta  Jan-2023          0.0248      0.0127                  47.84
# 2     Delta  Jan-2023          0.0062      0.0143                  59.58
# 3   Epsilon  Jan-2023         -0.0036      0.0148                  75.94
# 4       Eta  Jan-2023         -0.0041      0.0462                  65.50
#
#    Bond Allocation (%)  Cash Allocation (%)
# 0                16.24                19.81
# 1                11.81                40.35
# 2                49.43                -9.00
# 3                34.26               -10.20
# 4                39.04                -4.54
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8ec31d1b-2310-47c2-b6aa-78434dd06de6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ec31d1b-2310-47c2-b6aa-78434dd06de6")) {                    Plotly.newPlot(                        "8ec31d1b-2310-47c2-b6aa-78434dd06de6",                        [{"hovertemplate":"Fund Name=Alpha\u003cbr\u003eMonth=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alpha","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Alpha","orientation":"v","showlegend":true,"x":["Jan-2023","Feb-2023","Mar-2023","Apr-2023","May-2023","Jun-2023","Jul-2023","Aug-2023","Sep-2023","Oct-2023","Nov-2023","Dec-2023"],"xaxis":"x","y":[0.0199,0.0072,0.0416,0.0253,0.0148,-0.0283,0.0393,0.0055,-0.002,0.0042,0.0265,-0.0144],"yaxis":"y","type":"scatter"},{"hovertemplate":"Fund Name=Beta\u003cbr\u003eMonth=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Beta","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Beta","orientation":"v","showlegend":true,"x":["Jan-2023","Feb-2023","Mar-2023","Apr-2023","May-2023","Jun-2023","Jul-2023","Aug-2023","Sep-2023","Oct-2023","Nov-2023","Dec-2023"],"xaxis":"x","y":[0.0248,0.0134,0.0008,0.0311,-0.0035,0.0222,-0.0068,0.0038,0.0263,0.0371,0.0093,0.0413],"yaxis":"y","type":"scatter"},{"hovertemplate":"Fund Name=Delta\u003cbr\u003eMonth=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delta","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Delta","orientation":"v","showlegend":true,"x":["Jan-2023","Feb-2023","Mar-2023","Apr-2023","May-2023","Jun-2023","Jul-2023","Aug-2023","Sep-2023","Oct-2023","Nov-2023","Dec-2023"],"xaxis":"x","y":[0.0062,0.016,0.0258,-0.0082,-0.0098,-0.0013,-0.0112,0.0195,0.0263,-0.0146,0.0152,0.0256],"yaxis":"y","type":"scatter"},{"hovertemplate":"Fund Name=Epsilon\u003cbr\u003eMonth=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Epsilon","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Epsilon","orientation":"v","showlegend":true,"x":["Jan-2023","Feb-2023","Mar-2023","Apr-2023","May-2023","Jun-2023","Jul-2023","Aug-2023","Sep-2023","Oct-2023","Nov-2023","Dec-2023"],"xaxis":"x","y":[-0.0036,0.0146,0.0473,0.0195,0.0293,0.0183,0.0085,0.0168,0.0225,-0.0071,0.0055,0.0243],"yaxis":"y","type":"scatter"},{"hovertemplate":"Fund Name=Eta\u003cbr\u003eMonth=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eta","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Eta","orientation":"v","showlegend":true,"x":["Jan-2023","Feb-2023","Mar-2023","Apr-2023","May-2023","Jun-2023","Jul-2023","Aug-2023","Sep-2023","Oct-2023","Nov-2023","Dec-2023"],"xaxis":"x","y":[-0.0041,-0.018,-0.0182,0.012,-0.029,-0.0117,0.0374,0.0156,0.0039,0.0105,0.0276,-0.0336],"yaxis":"y","type":"scatter"},{"hovertemplate":"Fund Name=Gamma\u003cbr\u003eMonth=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gamma","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Gamma","orientation":"v","showlegend":true,"x":["Jan-2023","Feb-2023","Mar-2023","Apr-2023","May-2023","Jun-2023","Jul-2023","Aug-2023","Sep-2023","Oct-2023","Nov-2023","Dec-2023"],"xaxis":"x","y":[0.0118,-0.0298,-0.0062,0.0,0.0119,0.0294,0.0159,0.0152,0.0068,0.0181,-0.0284,0.0095],"yaxis":"y","type":"scatter"},{"hovertempl ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4d6589e1-6a07-4594-a0e7-dbaf0b699708" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d6589e1-6a07-4594-a0e7-dbaf0b699708")) {                    Plotly.newPlot(                        "4d6589e1-6a07-4594-a0e7-dbaf0b699708",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eFund Name=%{text}\u003cbr\u003eVolatility=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Alpha"],"legendgroup":"Alpha","marker":{"color":"#636efa","size":[5.0],"sizemode":"area","sizeref":0.0125,"symbol":"circle"},"mode":"markers+text","name":"Alpha","orientation":"v","showlegend":true,"text":["Alpha"],"x":[0.01905],"xaxis":"x","y":[0.011633333333333334],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eFund Name=%{text}\u003cbr\u003eVolatility=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Beta"],"legendgroup":"Beta","marker":{"color":"#EF553B","size":[5.0],"sizemode":"area","sizeref":0.0125,"symbol":"circle"},"mode":"markers+text","name":"Beta","orientation":"v","showlegend":true,"text":["Beta"],"x":[0.023483333333333332],"xaxis":"x","y":[0.01665],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eFund Name=%{text}\u003cbr\u003eVolatility=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Delta"],"legendgroup":"Delta","marker":{"color":"#00cc96","size":[5.0],"sizemode":"area","sizeref":0.0125,"symbol":"circle"},"mode":"markers+text","name":"Delta","orientation":"v","showlegend":true,"text":["Delta"],"x":[0.021175],"xaxis":"x","y":[0.007458333333333333],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eFund Name=%{text}\u003cbr\u003eVolatility=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Epsilon"],"legendgroup":"Epsilon","marker":{"color":"#ab63fa","size":[5.0],"sizemode":"area","sizeref":0.0125,"symbol":"circle"},"mode":"markers+text","name":"Epsilon","orientation":"v","showlegend":true,"text":["Epsilon"],"x":[0.0223],"xaxis":"x","y":[0.016325],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eFund Name=%{text}\u003cbr\u003eVolatility=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Eta"],"legendgroup":"Eta","marker":{"color":"#FFA15A","size":[5.0],"sizemode":"area","sizeref":0.0125,"symbol":"circle"},"mode":"markers+text","name":"Eta","orientation":"v","showlegend":true,"text":["Eta"],"x":[0.04794166666666667],"xaxis":"x","y":[-0.000633333333333333],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eFund Name=%{text}\u003cbr\u003eVolatility=%{x}\u003cbr\u003eMonthly Return=%{y}\u003cbr\u003eSize=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Gamma"],"legendgroup":"Gamma","marker":{"color":"#19d3f3","size":[5.0],"sizemode":"area","sizeref":0.0125,"symbol":"circle"},"mode":"markers+text","name":"Gamma","orientation":"v","showlegend":true,"text":["Gamma"],"x":[0.027225],"xaxis":"x","y":[0.004516666666 ...
# 📊 Average Monthly Returns:
#   Fund Name  Avg Monthly Return
# 0     Alpha            0.011633
# 1      Beta            0.016650
# 2     Delta            0.007458
# 3   Epsilon            0.016325
# 4       Eta           -0.000633
# 5     Gamma            0.004517
# 6      Zeta            0.000050
# ⚠️ Highest Risk Investment:
#   Fund Name Monthly Return Volatility Size
# 4       Eta      -0.000633   0.047942  5.0
# ✅ Lowest Risk Investment:
#   Fund Name Monthly Return Volatility Size
# 0     Alpha       0.011633    0.01905  5.0
# 🏆 Top 3 appearances:
# Fund Name
# Alpha      6
# Beta       7
# Delta      6
# Epsilon    8
# Eta        3
# Gamma      4
# Zeta       2
# dtype: int64
# ⬇️ Bottom 3 appearances:
# Fund Name
# Alpha      4
# Beta       3
# Delta      5
# Epsilon    3
# Eta        7
# Gamma      6
# Zeta       8
# dtype: int64
# 📉 Most Stable Allocation:
#   Fund Name Avg Allocation Std
# 2     Delta          11.176456
# 📈 Least Stable Allocation:
#   Fund Name Avg Allocation Std
# 3   Epsilon          14.076396
# 💵 Cash Allocation Validation (sample rows):
#       Month Fund Name  Equity Allocation (%)  Bond Allocation (%)  \
# 0  Jan-2023     Alpha                  63.95                16.24
# 1  Jan-2023      Beta                  47.84                11.81
# 2  Jan-2023     Delta                  59.58                49.43
# 3  Jan-2023   Epsilon                  75.94                34.26
# 4  Jan-2023       Eta                  65.50                39.04
#
#    Cash Allocation (%)  Cash Corrected  Total Alloc
# 0                19.81    1.981000e+01       100.00
# 1                40.35    4.035000e+01       100.00
# 2                -9.00   -1.000000e-02       100.01
# 3               -10.20    1.421085e-14       100.00
# 4                -4.54    1.421085e-14       100.00
# 📑 Fund Summary Report:
#   Fund Name  Avg Return  Avg Risk  Avg Equity  Avg Bonds   Avg Cash
# 0     Alpha    0.011633  0.019050   58.260000  30.441667  14.788333
# 1      Beta    0.016650  0.023483   58.050000  24.080833  19.016667
# 2     Delta    0.007458  0.021175   58.665000  37.010833   7.435833
# 3   Epsilon    0.016325  0.022300   61.493333  34.115000  10.220833
# 4       Eta   -0.000633  0.047942   53.535000  27.425833  20.723333
# 5     Gamma    0.004517  0.027225   58.660833  24.370833  17.606667
# 6      Zeta    0.000050  0.046917   64.295833  31.400833   9.053333
# interactive(children=(FloatSlider(value=0.05, description='Max Risk', max=0.1, step=0.005), FloatSlider(value=…
# <function __main__.fund_selector(max_risk, min_return)>
